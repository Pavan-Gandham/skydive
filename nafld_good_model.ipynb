# %% [markdown]
# # Model - 1 - CNN Model (Best Model)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score,accuracy_score

# Load the dataset
#df = pd.read_csv('data.csv')

# Preprocess the data (e.g., handle missing values, normalize/scale features)

# Split the dataset into training and validation sets
df = pd.read_csv('train.csv')
train_data1 = df.iloc[:, [7, 8, 21, 22, 24, 25, 27, 29]]
train_labels = df.iloc[:, [0]]
dftest = pd.read_csv('test.csv')
val_data1 = dftest.iloc[:, [7, 8, 21, 22, 24, 25, 27, 29]]
val_labels = dftest.iloc[:, [0]]

# Create an instance of StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data
scaler.fit(train_data1)

# Scale the training data
train_data = scaler.transform(train_data1)
train_l = train_labels.to_numpy()
# Scale the validation data
val_data = scaler.transform(val_data1)
val_l = val_labels.to_numpy()
# Reshape the data for CNN input
train_data = train_data.reshape(train_data.shape[0], train_data.shape[1], 1)
val_data = val_data.reshape(val_data.shape[0], val_data.shape[1], 1)

# Define the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(train_data.shape[1], 1)))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# Define the number of folds for cross-validation
num_folds = 7

# Perform k-fold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True)

train_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
auc_roc_scores = []
val_scores = []
best_model = None
best_auc_roc = 0.0
for train_index, val_index in kf.split(train_data):
    # Split the data into training and validation sets for the current fold
    train_fold_data, val_fold_data = train_data[train_index], train_data[val_index]
    train_fold_labels, val_fold_labels = train_l[train_index], train_l[val_index]

    # Train the model on the current fold
    history = model.fit(train_fold_data, train_fold_labels, epochs=50, batch_size=32, validation_data=(val_fold_data, val_fold_labels))

    # Evaluate the model on the training and validation sets of the current fold
    train_predictions = model.predict(train_fold_data)
    val_predictions = model.predict(val_fold_data)
    val_predictions = np.round(val_predictions)

    # Calculate accuracy scores for training and validation sets
    train_acc = model.evaluate(train_fold_data, train_fold_labels, verbose=0)[1]
    val_acc = model.evaluate(val_fold_data, val_fold_labels, verbose=0)[1]

    train_scores.append(train_acc)
    val_scores.append(val_acc)
    
    auc_roc = roc_auc_score(val_fold_labels, val_predictions)
    
    precision = precision_score(val_fold_labels, val_predictions)
    recall = recall_score(val_fold_labels, val_predictions)
    f1 = f1_score(val_fold_labels, val_predictions)
    auc_roc = roc_auc_score(val_fold_labels, val_predictions)

    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)
    auc_roc_scores.append(auc_roc)


# Compute the average scores across all folds
avg_precision = np.mean(precision_scores)
avg_recall = np.mean(recall_scores)
avg_f1 = np.mean(f1_scores)
avg_auc_roc = np.mean(auc_roc_scores)
avg_val_acc=np.mean(val_scores)
avg_train_acc=np.mean(train_scores)
print('Average Precision:', avg_precision)
print('Average Recall:', avg_recall)
print('Average F1-score:', avg_f1)
print('Average AUC-ROC:', avg_auc_roc)
print('average val accuracy',avg_val_acc)
print('average train accuracy',avg_train_acc)
# Calculate bias and variance

# Plot bias and variance
# plt.bar(['Bias', 'Variance'], [bias, variance])
# plt.xlabel('Error Type')
# plt.ylabel('Error Value')
# plt.title('Bias-Variance Tradeoff')
# plt.show()
# Out:
# Epoch 1/50
# 61/61 [==============================] - 1s 5ms/step - loss: 0.5717 - accuracy: 0.7300 - val_loss: 0.5075 - val_accuracy: 0.7747
# Epoch 2/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.5076 - accuracy: 0.7702 - val_loss: 0.5029 - val_accuracy: 0.7593
# Epoch 3/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.5011 - accuracy: 0.7702 - val_loss: 0.5054 - val_accuracy: 0.7840
# Epoch 4/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4945 - accuracy: 0.7718 - val_loss: 0.5087 - val_accuracy: 0.7654
# Epoch 5/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4926 - accuracy: 0.7852 - val_loss: 0.5025 - val_accuracy: 0.7654
# Epoch 6/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4892 - accuracy: 0.7810 - val_loss: 0.5076 - val_accuracy: 0.7716
# Epoch 7/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4874 - accuracy: 0.7749 - val_loss: 0.5167 - val_accuracy: 0.7685
# Epoch 8/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4842 - accuracy: 0.7816 - val_loss: 0.5071 - val_accuracy: 0.7654
# Epoch 9/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4774 - accuracy: 0.7826 - val_loss: 0.5212 - val_accuracy: 0.7654
# Epoch 10/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4772 - accuracy: 0.7831 - val_loss: 0.5339 - val_accuracy: 0.7469
# Epoch 11/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4755 - accuracy: 0.7774 - val_loss: 0.5258 - val_accuracy: 0.7407
# Epoch 12/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4719 - accuracy: 0.7888 - val_loss: 0.5174 - val_accuracy: 0.7623
# Epoch 13/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.4687 - accuracy: 0.7913 - val_loss: 0.5036 - val_accuracy: 0.7562
# Epoch 14/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.7970 - val_loss: 0.5236 - val_accuracy: 0.7531
# Epoch 15/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7939 - val_loss: 0.5183 - val_accuracy: 0.7593
# Epoch 16/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4625 - accuracy: 0.7944 - val_loss: 0.5068 - val_accuracy: 0.7716
# Epoch 17/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4577 - accuracy: 0.8006 - val_loss: 0.5111 - val_accuracy: 0.7531
# Epoch 18/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.8001 - val_loss: 0.5105 - val_accuracy: 0.7716
# Epoch 19/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.7996 - val_loss: 0.5121 - val_accuracy: 0.7623
# Epoch 20/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4557 - accuracy: 0.8032 - val_loss: 0.5187 - val_accuracy: 0.7685
# Epoch 21/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4476 - accuracy: 0.8068 - val_loss: 0.5277 - val_accuracy: 0.7500
# Epoch 22/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4420 - accuracy: 0.8073 - val_loss: 0.5097 - val_accuracy: 0.7531
# Epoch 23/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.8120 - val_loss: 0.5282 - val_accuracy: 0.7562
# Epoch 24/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4398 - accuracy: 0.8104 - val_loss: 0.5168 - val_accuracy: 0.7562
# Epoch 25/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.8130 - val_loss: 0.5126 - val_accuracy: 0.7716
# Epoch 26/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4348 - accuracy: 0.8058 - val_loss: 0.5526 - val_accuracy: 0.7469
# Epoch 27/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.8053 - val_loss: 0.5369 - val_accuracy: 0.7531
# Epoch 28/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4245 - accuracy: 0.8161 - val_loss: 0.5225 - val_accuracy: 0.7623
# Epoch 29/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4282 - accuracy: 0.8171 - val_loss: 0.5210 - val_accuracy: 0.7685
# Epoch 30/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4224 - accuracy: 0.8130 - val_loss: 0.5364 - val_accuracy: 0.7531
# Epoch 31/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4180 - accuracy: 0.8140 - val_loss: 0.5320 - val_accuracy: 0.7562
# Epoch 32/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4151 - accuracy: 0.8181 - val_loss: 0.5560 - val_accuracy: 0.7407
# Epoch 33/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4175 - accuracy: 0.8181 - val_loss: 0.5537 - val_accuracy: 0.7438
# Epoch 34/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4121 - accuracy: 0.8181 - val_loss: 0.5918 - val_accuracy: 0.7253
# Epoch 35/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4121 - accuracy: 0.8228 - val_loss: 0.5479 - val_accuracy: 0.7500
# Epoch 36/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4044 - accuracy: 0.8253 - val_loss: 0.5285 - val_accuracy: 0.7685
# Epoch 37/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3962 - accuracy: 0.8326 - val_loss: 0.5497 - val_accuracy: 0.7346
# Epoch 38/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3913 - accuracy: 0.8326 - val_loss: 0.5820 - val_accuracy: 0.7562
# Epoch 39/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8310 - val_loss: 0.5608 - val_accuracy: 0.7222
# Epoch 40/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4015 - accuracy: 0.8197 - val_loss: 0.5801 - val_accuracy: 0.7315
# Epoch 41/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3878 - accuracy: 0.8315 - val_loss: 0.5621 - val_accuracy: 0.7469
# Epoch 42/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.8377 - val_loss: 0.5733 - val_accuracy: 0.7284
# Epoch 43/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3813 - accuracy: 0.8320 - val_loss: 0.6246 - val_accuracy: 0.7407
# Epoch 44/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8403 - val_loss: 0.5418 - val_accuracy: 0.7531
# Epoch 45/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3727 - accuracy: 0.8367 - val_loss: 0.6404 - val_accuracy: 0.7346
# Epoch 46/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8393 - val_loss: 0.5733 - val_accuracy: 0.7407
# Epoch 47/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3602 - accuracy: 0.8470 - val_loss: 0.5967 - val_accuracy: 0.7315
# Epoch 48/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3638 - accuracy: 0.8485 - val_loss: 0.5873 - val_accuracy: 0.7438
# Epoch 49/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3864 - accuracy: 0.8367 - val_loss: 0.6032 - val_accuracy: 0.7377
# Epoch 50/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3645 - accuracy: 0.8470 - val_loss: 0.5856 - val_accuracy: 0.7500
# 61/61 [==============================] - 0s 996us/step
# 11/11 [==============================] - 0s 2ms/step
# Epoch 1/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.4017 - accuracy: 0.8341 - val_loss: 0.3625 - val_accuracy: 0.8519
# Epoch 2/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.4026 - accuracy: 0.8310 - val_loss: 0.3799 - val_accuracy: 0.8364
# Epoch 3/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3853 - accuracy: 0.8305 - val_loss: 0.3976 - val_accuracy: 0.8210
# Epoch 4/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3931 - accuracy: 0.8305 - val_loss: 0.3993 - val_accuracy: 0.8148
# Epoch 5/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.8398 - val_loss: 0.3874 - val_accuracy: 0.8272
# Epoch 6/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3661 - accuracy: 0.8418 - val_loss: 0.4467 - val_accuracy: 0.7963
# Epoch 7/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3960 - accuracy: 0.8310 - val_loss: 0.4173 - val_accuracy: 0.8086
# Epoch 8/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8408 - val_loss: 0.4228 - val_accuracy: 0.8117
# Epoch 9/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3546 - accuracy: 0.8506 - val_loss: 0.4123 - val_accuracy: 0.8179
# Epoch 10/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8341 - val_loss: 0.4112 - val_accuracy: 0.8210
# Epoch 11/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3553 - accuracy: 0.8434 - val_loss: 0.3938 - val_accuracy: 0.8333
# Epoch 12/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3556 - accuracy: 0.8532 - val_loss: 0.3945 - val_accuracy: 0.8395
# Epoch 13/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3511 - accuracy: 0.8557 - val_loss: 0.4146 - val_accuracy: 0.8241
# Epoch 14/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3529 - accuracy: 0.8480 - val_loss: 0.4329 - val_accuracy: 0.8241
# Epoch 15/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8578 - val_loss: 0.4341 - val_accuracy: 0.7963
# Epoch 16/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3434 - accuracy: 0.8527 - val_loss: 0.4079 - val_accuracy: 0.8025
# Epoch 17/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8609 - val_loss: 0.4354 - val_accuracy: 0.8241
# Epoch 18/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3468 - accuracy: 0.8501 - val_loss: 0.4272 - val_accuracy: 0.8210
# Epoch 19/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3353 - accuracy: 0.8594 - val_loss: 0.4233 - val_accuracy: 0.8241
# Epoch 20/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3221 - accuracy: 0.8588 - val_loss: 0.4212 - val_accuracy: 0.8025
# Epoch 21/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8563 - val_loss: 0.4066 - val_accuracy: 0.8210
# Epoch 22/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3222 - accuracy: 0.8650 - val_loss: 0.4461 - val_accuracy: 0.8056
# Epoch 23/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3197 - accuracy: 0.8660 - val_loss: 0.4292 - val_accuracy: 0.8056
# Epoch 24/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3162 - accuracy: 0.8624 - val_loss: 0.4712 - val_accuracy: 0.7994
# Epoch 25/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3109 - accuracy: 0.8717 - val_loss: 0.4293 - val_accuracy: 0.8117
# Epoch 26/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3092 - accuracy: 0.8717 - val_loss: 0.4293 - val_accuracy: 0.8241
# Epoch 27/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.8599 - val_loss: 0.4224 - val_accuracy: 0.8210
# Epoch 28/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3019 - accuracy: 0.8810 - val_loss: 0.4483 - val_accuracy: 0.8086
# Epoch 29/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3015 - accuracy: 0.8743 - val_loss: 0.4864 - val_accuracy: 0.8086
# Epoch 30/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3057 - accuracy: 0.8681 - val_loss: 0.4584 - val_accuracy: 0.7932
# Epoch 31/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3017 - accuracy: 0.8727 - val_loss: 0.4438 - val_accuracy: 0.8056
# Epoch 32/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2916 - accuracy: 0.8784 - val_loss: 0.4467 - val_accuracy: 0.8056
# Epoch 33/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2896 - accuracy: 0.8779 - val_loss: 0.4830 - val_accuracy: 0.7870
# Epoch 34/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2863 - accuracy: 0.8861 - val_loss: 0.4578 - val_accuracy: 0.8148
# Epoch 35/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2785 - accuracy: 0.8841 - val_loss: 0.4598 - val_accuracy: 0.8210
# Epoch 36/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.8784 - val_loss: 0.6045 - val_accuracy: 0.7809
# Epoch 37/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2888 - accuracy: 0.8784 - val_loss: 0.4743 - val_accuracy: 0.7901
# Epoch 38/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2820 - accuracy: 0.8836 - val_loss: 0.4746 - val_accuracy: 0.8056
# Epoch 39/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2705 - accuracy: 0.8928 - val_loss: 0.4854 - val_accuracy: 0.8025
# Epoch 40/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2674 - accuracy: 0.8944 - val_loss: 0.5066 - val_accuracy: 0.7870
# Epoch 41/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2814 - accuracy: 0.8897 - val_loss: 0.5169 - val_accuracy: 0.7747
# Epoch 42/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3055 - accuracy: 0.8794 - val_loss: 0.5226 - val_accuracy: 0.7747
# Epoch 43/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2992 - accuracy: 0.8815 - val_loss: 0.4938 - val_accuracy: 0.7778
# Epoch 44/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2779 - accuracy: 0.8877 - val_loss: 0.5337 - val_accuracy: 0.7963
# Epoch 45/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2674 - accuracy: 0.8913 - val_loss: 0.5082 - val_accuracy: 0.7778
# Epoch 46/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.9026 - val_loss: 0.4950 - val_accuracy: 0.7994
# Epoch 47/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2444 - accuracy: 0.8990 - val_loss: 0.5154 - val_accuracy: 0.7840
# Epoch 48/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2574 - accuracy: 0.9001 - val_loss: 0.5267 - val_accuracy: 0.7870
# Epoch 49/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2480 - accuracy: 0.8944 - val_loss: 0.5227 - val_accuracy: 0.7747
# Epoch 50/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.9057 - val_loss: 0.5283 - val_accuracy: 0.7963
# 61/61 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 2ms/step
# Epoch 1/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.3060 - accuracy: 0.8794 - val_loss: 0.2256 - val_accuracy: 0.9012
# Epoch 2/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3010 - accuracy: 0.8815 - val_loss: 0.2788 - val_accuracy: 0.9074
# Epoch 3/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.3039 - accuracy: 0.8779 - val_loss: 0.2906 - val_accuracy: 0.8673
# Epoch 4/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2909 - accuracy: 0.8825 - val_loss: 0.2611 - val_accuracy: 0.9043
# Epoch 5/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2784 - accuracy: 0.8841 - val_loss: 0.2445 - val_accuracy: 0.9074
# Epoch 6/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2736 - accuracy: 0.8856 - val_loss: 0.2973 - val_accuracy: 0.8704
# Epoch 7/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2749 - accuracy: 0.8846 - val_loss: 0.2916 - val_accuracy: 0.8858
# Epoch 8/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2682 - accuracy: 0.8892 - val_loss: 0.2895 - val_accuracy: 0.8796
# Epoch 9/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2523 - accuracy: 0.9088 - val_loss: 0.2752 - val_accuracy: 0.8858
# Epoch 10/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2465 - accuracy: 0.9026 - val_loss: 0.2924 - val_accuracy: 0.8827
# Epoch 11/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2501 - accuracy: 0.8949 - val_loss: 0.2729 - val_accuracy: 0.8827
# Epoch 12/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2486 - accuracy: 0.8995 - val_loss: 0.2909 - val_accuracy: 0.8858
# Epoch 13/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2547 - accuracy: 0.9016 - val_loss: 0.3259 - val_accuracy: 0.8611
# Epoch 14/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.9062 - val_loss: 0.3038 - val_accuracy: 0.8673
# Epoch 15/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2413 - accuracy: 0.9016 - val_loss: 0.4279 - val_accuracy: 0.8302
# Epoch 16/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.9037 - val_loss: 0.3025 - val_accuracy: 0.8796
# Epoch 17/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2534 - accuracy: 0.8944 - val_loss: 0.3134 - val_accuracy: 0.8580
# Epoch 18/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2387 - accuracy: 0.8985 - val_loss: 0.3343 - val_accuracy: 0.8704
# Epoch 19/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2211 - accuracy: 0.9165 - val_loss: 0.3656 - val_accuracy: 0.8580
# Epoch 20/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2255 - accuracy: 0.9078 - val_loss: 0.3871 - val_accuracy: 0.8333
# Epoch 21/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2427 - accuracy: 0.8975 - val_loss: 0.3808 - val_accuracy: 0.8426
# Epoch 22/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2123 - accuracy: 0.9196 - val_loss: 0.3593 - val_accuracy: 0.8519
# Epoch 23/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2418 - accuracy: 0.9006 - val_loss: 0.3806 - val_accuracy: 0.8333
# Epoch 24/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2546 - accuracy: 0.8944 - val_loss: 0.4584 - val_accuracy: 0.8148
# Epoch 25/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2120 - accuracy: 0.9160 - val_loss: 0.3368 - val_accuracy: 0.8549
# Epoch 26/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2102 - accuracy: 0.9181 - val_loss: 0.3568 - val_accuracy: 0.8642
# Epoch 27/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2023 - accuracy: 0.9217 - val_loss: 0.4000 - val_accuracy: 0.8549
# Epoch 28/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2077 - accuracy: 0.9165 - val_loss: 0.3888 - val_accuracy: 0.8549
# Epoch 29/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1935 - accuracy: 0.9299 - val_loss: 0.3839 - val_accuracy: 0.8642
# Epoch 30/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.9201 - val_loss: 0.4635 - val_accuracy: 0.8302
# Epoch 31/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2134 - accuracy: 0.9191 - val_loss: 0.4139 - val_accuracy: 0.8488
# Epoch 32/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2077 - accuracy: 0.9119 - val_loss: 0.4345 - val_accuracy: 0.8457
# Epoch 33/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1911 - accuracy: 0.9186 - val_loss: 0.4678 - val_accuracy: 0.8426
# Epoch 34/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1992 - accuracy: 0.9263 - val_loss: 0.3698 - val_accuracy: 0.8488
# Epoch 35/50
# 61/61 [==============================] - 0s 5ms/step - loss: 0.2169 - accuracy: 0.9176 - val_loss: 0.4802 - val_accuracy: 0.8395
# Epoch 36/50
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1943 - accuracy: 0.9227 - val_loss: 0.4000 - val_accuracy: 0.8241
# Epoch 37/50
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1952 - accuracy: 0.9274 - val_loss: 0.3590 - val_accuracy: 0.8549
# Epoch 38/50
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1813 - accuracy: 0.9253 - val_loss: 0.4112 - val_accuracy: 0.8426
# Epoch 39/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1846 - accuracy: 0.9289 - val_loss: 0.4526 - val_accuracy: 0.8210
# Epoch 40/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9351 - val_loss: 0.4099 - val_accuracy: 0.8241
# Epoch 41/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1671 - accuracy: 0.9387 - val_loss: 0.4592 - val_accuracy: 0.8272
# Epoch 42/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1760 - accuracy: 0.9294 - val_loss: 0.4447 - val_accuracy: 0.8364
# Epoch 43/50
# 61/61 [==============================] - 0s 6ms/step - loss: 0.1618 - accuracy: 0.9402 - val_loss: 0.4574 - val_accuracy: 0.8333
# Epoch 44/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1546 - accuracy: 0.9474 - val_loss: 0.4806 - val_accuracy: 0.8272
# Epoch 45/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 0.9294 - val_loss: 0.4768 - val_accuracy: 0.8488
# Epoch 46/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1626 - accuracy: 0.9397 - val_loss: 0.4559 - val_accuracy: 0.8272
# Epoch 47/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1554 - accuracy: 0.9397 - val_loss: 0.5032 - val_accuracy: 0.8395
# Epoch 48/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1606 - accuracy: 0.9346 - val_loss: 0.5065 - val_accuracy: 0.8364
# Epoch 49/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.9428 - val_loss: 0.4520 - val_accuracy: 0.8364
# Epoch 50/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1426 - accuracy: 0.9490 - val_loss: 0.4507 - val_accuracy: 0.8333
# 61/61 [==============================] - 0s 974us/step
# 11/11 [==============================] - 0s 2ms/step
# Epoch 1/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.2477 - accuracy: 0.9042 - val_loss: 0.2032 - val_accuracy: 0.9105
# Epoch 2/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.9201 - val_loss: 0.2410 - val_accuracy: 0.8981
# Epoch 3/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.2469 - accuracy: 0.9073 - val_loss: 0.2858 - val_accuracy: 0.8642
# Epoch 4/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.2229 - accuracy: 0.9176 - val_loss: 0.2499 - val_accuracy: 0.8642
# Epoch 5/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1994 - accuracy: 0.9140 - val_loss: 0.2491 - val_accuracy: 0.8951
# Epoch 6/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1755 - accuracy: 0.9299 - val_loss: 0.2230 - val_accuracy: 0.9012
# Epoch 7/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1625 - accuracy: 0.9392 - val_loss: 0.2408 - val_accuracy: 0.8920
# Epoch 8/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.9428 - val_loss: 0.2365 - val_accuracy: 0.9012
# Epoch 9/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1475 - accuracy: 0.9438 - val_loss: 0.2410 - val_accuracy: 0.8796
# Epoch 10/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1510 - accuracy: 0.9408 - val_loss: 0.2381 - val_accuracy: 0.9012
# Epoch 11/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1539 - accuracy: 0.9377 - val_loss: 0.2408 - val_accuracy: 0.8796
# Epoch 12/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1379 - accuracy: 0.9495 - val_loss: 0.2656 - val_accuracy: 0.8796
# Epoch 13/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1439 - accuracy: 0.9423 - val_loss: 0.2776 - val_accuracy: 0.8765
# Epoch 14/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1797 - accuracy: 0.9356 - val_loss: 0.3171 - val_accuracy: 0.8735
# Epoch 15/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1617 - accuracy: 0.9433 - val_loss: 0.3639 - val_accuracy: 0.8735
# Epoch 16/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1562 - accuracy: 0.9459 - val_loss: 0.2929 - val_accuracy: 0.8796
# Epoch 17/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1311 - accuracy: 0.9521 - val_loss: 0.3109 - val_accuracy: 0.8796
# Epoch 18/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1385 - accuracy: 0.9464 - val_loss: 0.2722 - val_accuracy: 0.8827
# Epoch 19/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1258 - accuracy: 0.9557 - val_loss: 0.3449 - val_accuracy: 0.8735
# Epoch 20/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1215 - accuracy: 0.9552 - val_loss: 0.2695 - val_accuracy: 0.8796
# Epoch 21/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1283 - accuracy: 0.9541 - val_loss: 0.2974 - val_accuracy: 0.8796
# Epoch 22/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1379 - accuracy: 0.9454 - val_loss: 0.3709 - val_accuracy: 0.8580
# Epoch 23/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1324 - accuracy: 0.9521 - val_loss: 0.3727 - val_accuracy: 0.8642
# Epoch 24/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1112 - accuracy: 0.9583 - val_loss: 0.3395 - val_accuracy: 0.8673
# Epoch 25/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.9547 - val_loss: 0.3498 - val_accuracy: 0.8611
# Epoch 26/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1123 - accuracy: 0.9619 - val_loss: 0.3821 - val_accuracy: 0.8549
# Epoch 27/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9531 - val_loss: 0.3700 - val_accuracy: 0.8519
# Epoch 28/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1294 - accuracy: 0.9495 - val_loss: 0.3380 - val_accuracy: 0.8673
# Epoch 29/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1362 - accuracy: 0.9480 - val_loss: 0.4173 - val_accuracy: 0.8580
# Epoch 30/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1359 - accuracy: 0.9418 - val_loss: 0.3365 - val_accuracy: 0.8673
# Epoch 31/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1083 - accuracy: 0.9603 - val_loss: 0.3608 - val_accuracy: 0.8611
# Epoch 32/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9681 - val_loss: 0.3798 - val_accuracy: 0.8549
# Epoch 33/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 0.9639 - val_loss: 0.4377 - val_accuracy: 0.8457
# Epoch 34/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9665 - val_loss: 0.3928 - val_accuracy: 0.8642
# Epoch 35/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9578 - val_loss: 0.4116 - val_accuracy: 0.8519
# Epoch 36/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.9665 - val_loss: 0.3748 - val_accuracy: 0.8580
# Epoch 37/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0992 - accuracy: 0.9655 - val_loss: 0.4095 - val_accuracy: 0.8457
# Epoch 38/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1678 - accuracy: 0.9294 - val_loss: 0.4589 - val_accuracy: 0.8302
# Epoch 39/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1654 - accuracy: 0.9464 - val_loss: 0.5344 - val_accuracy: 0.8241
# Epoch 40/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1818 - accuracy: 0.9474 - val_loss: 0.6319 - val_accuracy: 0.8364
# Epoch 41/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1767 - accuracy: 0.9490 - val_loss: 0.5072 - val_accuracy: 0.8395
# Epoch 42/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1229 - accuracy: 0.9572 - val_loss: 0.3768 - val_accuracy: 0.8364
# Epoch 43/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1002 - accuracy: 0.9686 - val_loss: 0.3980 - val_accuracy: 0.8426
# Epoch 44/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1070 - accuracy: 0.9608 - val_loss: 0.4671 - val_accuracy: 0.8426
# Epoch 45/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1010 - accuracy: 0.9629 - val_loss: 0.4060 - val_accuracy: 0.8488
# Epoch 46/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0824 - accuracy: 0.9706 - val_loss: 0.4443 - val_accuracy: 0.8395
# Epoch 47/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9804 - val_loss: 0.4237 - val_accuracy: 0.8519
# Epoch 48/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9717 - val_loss: 0.5241 - val_accuracy: 0.8426
# Epoch 49/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9681 - val_loss: 0.4241 - val_accuracy: 0.8395
# Epoch 50/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0805 - accuracy: 0.9748 - val_loss: 0.5080 - val_accuracy: 0.8333
# 61/61 [==============================] - 0s 804us/step
# 11/11 [==============================] - 0s 1ms/step
# Epoch 1/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1883 - accuracy: 0.9351 - val_loss: 0.1178 - val_accuracy: 0.9628
# Epoch 2/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1489 - accuracy: 0.9495 - val_loss: 0.1202 - val_accuracy: 0.9505
# Epoch 3/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9423 - val_loss: 0.1268 - val_accuracy: 0.9598
# Epoch 4/50
# 61/61 [==============================] - 0s 5ms/step - loss: 0.1242 - accuracy: 0.9573 - val_loss: 0.1166 - val_accuracy: 0.9598
# Epoch 5/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9516 - val_loss: 0.1195 - val_accuracy: 0.9598
# Epoch 6/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1429 - accuracy: 0.9526 - val_loss: 0.1445 - val_accuracy: 0.9412
# Epoch 7/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1157 - accuracy: 0.9562 - val_loss: 0.1164 - val_accuracy: 0.9598
# Epoch 8/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1111 - accuracy: 0.9634 - val_loss: 0.1945 - val_accuracy: 0.9412
# Epoch 9/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1059 - accuracy: 0.9614 - val_loss: 0.1853 - val_accuracy: 0.9443
# Epoch 10/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.1030 - accuracy: 0.9634 - val_loss: 0.1286 - val_accuracy: 0.9598
# Epoch 11/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1051 - accuracy: 0.9629 - val_loss: 0.1589 - val_accuracy: 0.9443
# Epoch 12/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 0.9578 - val_loss: 0.1481 - val_accuracy: 0.9474
# Epoch 13/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1109 - accuracy: 0.9629 - val_loss: 0.1515 - val_accuracy: 0.9319
# Epoch 14/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 0.9676 - val_loss: 0.1340 - val_accuracy: 0.9443
# Epoch 15/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0865 - accuracy: 0.9732 - val_loss: 0.1551 - val_accuracy: 0.9350
# Epoch 16/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0882 - accuracy: 0.9691 - val_loss: 0.1725 - val_accuracy: 0.9164
# Epoch 17/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.9696 - val_loss: 0.1801 - val_accuracy: 0.9319
# Epoch 18/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1161 - accuracy: 0.9537 - val_loss: 0.1979 - val_accuracy: 0.9319
# Epoch 19/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1074 - accuracy: 0.9624 - val_loss: 0.1992 - val_accuracy: 0.9009
# Epoch 20/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9706 - val_loss: 0.1755 - val_accuracy: 0.9319
# Epoch 21/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9763 - val_loss: 0.1794 - val_accuracy: 0.9350
# Epoch 22/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 0.9825 - val_loss: 0.1498 - val_accuracy: 0.9474
# Epoch 23/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9809 - val_loss: 0.1867 - val_accuracy: 0.9257
# Epoch 24/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0850 - accuracy: 0.9696 - val_loss: 0.1959 - val_accuracy: 0.9319
# Epoch 25/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0742 - accuracy: 0.9773 - val_loss: 0.2301 - val_accuracy: 0.9195
# Epoch 26/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.1022 - accuracy: 0.9624 - val_loss: 0.1992 - val_accuracy: 0.9164
# Epoch 27/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0829 - accuracy: 0.9732 - val_loss: 0.1983 - val_accuracy: 0.9319
# Epoch 28/50
# 61/61 [==============================] - 0s 2ms/step - loss: 0.0857 - accuracy: 0.9727 - val_loss: 0.1936 - val_accuracy: 0.9226
# Epoch 29/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0866 - accuracy: 0.9732 - val_loss: 0.2615 - val_accuracy: 0.9164
# Epoch 30/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0990 - accuracy: 0.9655 - val_loss: 0.2435 - val_accuracy: 0.9071
# Epoch 31/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1244 - accuracy: 0.9542 - val_loss: 0.2210 - val_accuracy: 0.9071
# Epoch 32/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0809 - accuracy: 0.9706 - val_loss: 0.2429 - val_accuracy: 0.9071
# Epoch 33/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0615 - accuracy: 0.9794 - val_loss: 0.1953 - val_accuracy: 0.9164
# Epoch 34/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0625 - accuracy: 0.9804 - val_loss: 0.2210 - val_accuracy: 0.9133
# Epoch 35/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0639 - accuracy: 0.9784 - val_loss: 0.2064 - val_accuracy: 0.9195
# Epoch 36/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0601 - accuracy: 0.9815 - val_loss: 0.2526 - val_accuracy: 0.9195
# Epoch 37/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0720 - accuracy: 0.9737 - val_loss: 0.2394 - val_accuracy: 0.9009
# Epoch 38/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0736 - accuracy: 0.9763 - val_loss: 0.2543 - val_accuracy: 0.9040
# Epoch 39/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9763 - val_loss: 0.2070 - val_accuracy: 0.9288
# Epoch 40/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0600 - accuracy: 0.9779 - val_loss: 0.2255 - val_accuracy: 0.9133
# Epoch 41/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9573 - val_loss: 0.3353 - val_accuracy: 0.8947
# Epoch 42/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1312 - accuracy: 0.9567 - val_loss: 0.3053 - val_accuracy: 0.8885
# Epoch 43/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.2517 - accuracy: 0.9341 - val_loss: 0.2886 - val_accuracy: 0.9009
# Epoch 44/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0916 - accuracy: 0.9650 - val_loss: 0.2551 - val_accuracy: 0.9009
# Epoch 45/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0648 - accuracy: 0.9789 - val_loss: 0.2322 - val_accuracy: 0.8978
# Epoch 46/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0588 - accuracy: 0.9840 - val_loss: 0.2593 - val_accuracy: 0.8916
# Epoch 47/50
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0708 - accuracy: 0.9758 - val_loss: 0.2733 - val_accuracy: 0.8916
# Epoch 48/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0602 - accuracy: 0.9830 - val_loss: 0.2929 - val_accuracy: 0.9226
# Epoch 49/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0633 - accuracy: 0.9794 - val_loss: 0.2616 - val_accuracy: 0.9164
# Epoch 50/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 0.9871 - val_loss: 0.2360 - val_accuracy: 0.9195
# 61/61 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# Epoch 1/50
# 61/61 [==============================] - 0s 5ms/step - loss: 0.1334 - accuracy: 0.9578 - val_loss: 0.1068 - val_accuracy: 0.9505
# Epoch 2/50
# 61/61 [==============================] - 0s 5ms/step - loss: 0.1857 - accuracy: 0.9387 - val_loss: 0.1041 - val_accuracy: 0.9659
# Epoch 3/50
# 61/61 [==============================] - 0s 5ms/step - loss: 0.1631 - accuracy: 0.9434 - val_loss: 0.1625 - val_accuracy: 0.9381
# Epoch 4/50
# 61/61 [==============================] - 0s 5ms/step - loss: 0.1168 - accuracy: 0.9614 - val_loss: 0.0949 - val_accuracy: 0.9505
# Epoch 5/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.1021 - accuracy: 0.9706 - val_loss: 0.1507 - val_accuracy: 0.9474
# Epoch 6/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0821 - accuracy: 0.9753 - val_loss: 0.0941 - val_accuracy: 0.9690
# Epoch 7/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 0.9763 - val_loss: 0.0772 - val_accuracy: 0.9814
# Epoch 8/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0682 - accuracy: 0.9779 - val_loss: 0.0963 - val_accuracy: 0.9752
# Epoch 9/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0591 - accuracy: 0.9856 - val_loss: 0.0799 - val_accuracy: 0.9752
# Epoch 10/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0630 - accuracy: 0.9815 - val_loss: 0.0732 - val_accuracy: 0.9721
# Epoch 11/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9799 - val_loss: 0.1033 - val_accuracy: 0.9721
# Epoch 12/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0546 - accuracy: 0.9861 - val_loss: 0.0778 - val_accuracy: 0.9783
# Epoch 13/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9871 - val_loss: 0.0789 - val_accuracy: 0.9721
# Epoch 14/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0530 - accuracy: 0.9846 - val_loss: 0.0795 - val_accuracy: 0.9814
# Epoch 15/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0522 - accuracy: 0.9840 - val_loss: 0.1057 - val_accuracy: 0.9598
# Epoch 16/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 0.9804 - val_loss: 0.1230 - val_accuracy: 0.9659
# Epoch 17/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0699 - accuracy: 0.9763 - val_loss: 0.1516 - val_accuracy: 0.9505
# Epoch 18/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1026 - accuracy: 0.9598 - val_loss: 0.1251 - val_accuracy: 0.9598
# Epoch 19/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 0.9681 - val_loss: 0.1427 - val_accuracy: 0.9381
# Epoch 20/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9681 - val_loss: 0.1493 - val_accuracy: 0.9536
# Epoch 21/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0912 - accuracy: 0.9691 - val_loss: 0.2654 - val_accuracy: 0.9226
# Epoch 22/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9701 - val_loss: 0.1198 - val_accuracy: 0.9598
# Epoch 23/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0525 - accuracy: 0.9856 - val_loss: 0.1098 - val_accuracy: 0.9598
# Epoch 24/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9897 - val_loss: 0.1179 - val_accuracy: 0.9721
# Epoch 25/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0528 - accuracy: 0.9835 - val_loss: 0.1343 - val_accuracy: 0.9628
# Epoch 26/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9892 - val_loss: 0.1044 - val_accuracy: 0.9628
# Epoch 27/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9856 - val_loss: 0.1465 - val_accuracy: 0.9567
# Epoch 28/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0537 - accuracy: 0.9820 - val_loss: 0.1625 - val_accuracy: 0.9474
# Epoch 29/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0489 - accuracy: 0.9856 - val_loss: 0.1259 - val_accuracy: 0.9659
# Epoch 30/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0395 - accuracy: 0.9897 - val_loss: 0.1284 - val_accuracy: 0.9567
# Epoch 31/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 0.9892 - val_loss: 0.1238 - val_accuracy: 0.9628
# Epoch 32/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0402 - accuracy: 0.9887 - val_loss: 0.1736 - val_accuracy: 0.9567
# Epoch 33/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 0.9840 - val_loss: 0.1271 - val_accuracy: 0.9505
# Epoch 34/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9887 - val_loss: 0.1042 - val_accuracy: 0.9659
# Epoch 35/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0415 - accuracy: 0.9882 - val_loss: 0.1046 - val_accuracy: 0.9536
# Epoch 36/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9779 - val_loss: 0.1597 - val_accuracy: 0.9443
# Epoch 37/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9763 - val_loss: 0.1554 - val_accuracy: 0.9505
# Epoch 38/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1302 - accuracy: 0.9542 - val_loss: 0.3805 - val_accuracy: 0.8947
# Epoch 39/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.2310 - accuracy: 0.9233 - val_loss: 0.2584 - val_accuracy: 0.9164
# Epoch 40/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.4549 - accuracy: 0.9089 - val_loss: 0.5723 - val_accuracy: 0.8700
# Epoch 41/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1799 - accuracy: 0.9346 - val_loss: 0.2434 - val_accuracy: 0.9133
# Epoch 42/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0728 - accuracy: 0.9706 - val_loss: 0.2336 - val_accuracy: 0.9381
# Epoch 43/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 0.9876 - val_loss: 0.2198 - val_accuracy: 0.9319
# Epoch 44/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9897 - val_loss: 0.2021 - val_accuracy: 0.9381
# Epoch 45/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0359 - accuracy: 0.9933 - val_loss: 0.2128 - val_accuracy: 0.9350
# Epoch 46/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9918 - val_loss: 0.1893 - val_accuracy: 0.9381
# Epoch 47/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9923 - val_loss: 0.1836 - val_accuracy: 0.9381
# Epoch 48/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0358 - accuracy: 0.9918 - val_loss: 0.2252 - val_accuracy: 0.9381
# Epoch 49/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0366 - accuracy: 0.9918 - val_loss: 0.1963 - val_accuracy: 0.9412
# Epoch 50/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 0.9902 - val_loss: 0.1972 - val_accuracy: 0.9381
# 61/61 [==============================] - 0s 2ms/step
# 11/11 [==============================] - 0s 2ms/step
# Epoch 1/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0882 - accuracy: 0.9722 - val_loss: 0.1314 - val_accuracy: 0.9505
# Epoch 2/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1028 - accuracy: 0.9640 - val_loss: 0.0802 - val_accuracy: 0.9690
# Epoch 3/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0789 - accuracy: 0.9717 - val_loss: 0.0660 - val_accuracy: 0.9752
# Epoch 4/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9840 - val_loss: 0.0576 - val_accuracy: 0.9783
# Epoch 5/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0590 - accuracy: 0.9789 - val_loss: 0.0718 - val_accuracy: 0.9690
# Epoch 6/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 0.9861 - val_loss: 0.0666 - val_accuracy: 0.9783
# Epoch 7/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 0.9882 - val_loss: 0.0519 - val_accuracy: 0.9845
# Epoch 8/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0377 - accuracy: 0.9892 - val_loss: 0.0674 - val_accuracy: 0.9690
# Epoch 9/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9892 - val_loss: 0.0683 - val_accuracy: 0.9690
# Epoch 10/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9902 - val_loss: 0.0619 - val_accuracy: 0.9783
# Epoch 11/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9907 - val_loss: 0.0824 - val_accuracy: 0.9721
# Epoch 12/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0401 - accuracy: 0.9887 - val_loss: 0.0712 - val_accuracy: 0.9752
# Epoch 13/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0352 - accuracy: 0.9892 - val_loss: 0.0811 - val_accuracy: 0.9628
# Epoch 14/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0279 - accuracy: 0.9938 - val_loss: 0.0691 - val_accuracy: 0.9721
# Epoch 15/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0313 - accuracy: 0.9912 - val_loss: 0.0712 - val_accuracy: 0.9659
# Epoch 16/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 0.9876 - val_loss: 0.0910 - val_accuracy: 0.9659
# Epoch 17/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9892 - val_loss: 0.0984 - val_accuracy: 0.9567
# Epoch 18/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 0.9866 - val_loss: 0.1063 - val_accuracy: 0.9598
# Epoch 19/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 0.9753 - val_loss: 0.1200 - val_accuracy: 0.9505
# Epoch 20/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1056 - accuracy: 0.9686 - val_loss: 0.2141 - val_accuracy: 0.9009
# Epoch 21/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0755 - accuracy: 0.9717 - val_loss: 0.1072 - val_accuracy: 0.9598
# Epoch 22/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0755 - accuracy: 0.9794 - val_loss: 0.1490 - val_accuracy: 0.9443
# Epoch 23/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0466 - accuracy: 0.9856 - val_loss: 0.1019 - val_accuracy: 0.9628
# Epoch 24/50
# 61/61 [==============================] - 0s 5ms/step - loss: 0.0385 - accuracy: 0.9892 - val_loss: 0.1011 - val_accuracy: 0.9598
# Epoch 25/50
# 61/61 [==============================] - 0s 6ms/step - loss: 0.0294 - accuracy: 0.9933 - val_loss: 0.1053 - val_accuracy: 0.9628
# Epoch 26/50
# 61/61 [==============================] - 0s 6ms/step - loss: 0.0285 - accuracy: 0.9928 - val_loss: 0.1783 - val_accuracy: 0.9474
# Epoch 27/50
# 61/61 [==============================] - 0s 6ms/step - loss: 0.0355 - accuracy: 0.9892 - val_loss: 0.0981 - val_accuracy: 0.9659
# Epoch 28/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0293 - accuracy: 0.9928 - val_loss: 0.1074 - val_accuracy: 0.9598
# Epoch 29/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0210 - accuracy: 0.9964 - val_loss: 0.1127 - val_accuracy: 0.9567
# Epoch 30/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9949 - val_loss: 0.1067 - val_accuracy: 0.9598
# Epoch 31/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9954 - val_loss: 0.1019 - val_accuracy: 0.9659
# Epoch 32/50
# 61/61 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9985 - val_loss: 0.1122 - val_accuracy: 0.9598
# Epoch 33/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0178 - accuracy: 0.9969 - val_loss: 0.1071 - val_accuracy: 0.9567
# Epoch 34/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0254 - accuracy: 0.9928 - val_loss: 0.1221 - val_accuracy: 0.9505
# Epoch 35/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.9954 - val_loss: 0.1065 - val_accuracy: 0.9598
# Epoch 36/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0221 - accuracy: 0.9943 - val_loss: 0.1095 - val_accuracy: 0.9628
# Epoch 37/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0374 - accuracy: 0.9882 - val_loss: 0.1296 - val_accuracy: 0.9598
# Epoch 38/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0947 - accuracy: 0.9681 - val_loss: 0.3307 - val_accuracy: 0.8854
# Epoch 39/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.2538 - accuracy: 0.9150 - val_loss: 0.3034 - val_accuracy: 0.9133
# Epoch 40/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1424 - accuracy: 0.9526 - val_loss: 0.2630 - val_accuracy: 0.9102
# Epoch 41/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.2082 - accuracy: 0.9418 - val_loss: 0.3422 - val_accuracy: 0.9102
# Epoch 42/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.1521 - accuracy: 0.9485 - val_loss: 0.2116 - val_accuracy: 0.9195
# Epoch 43/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0819 - accuracy: 0.9712 - val_loss: 0.1768 - val_accuracy: 0.9381
# Epoch 44/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0625 - accuracy: 0.9763 - val_loss: 0.2692 - val_accuracy: 0.9164
# Epoch 45/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0428 - accuracy: 0.9866 - val_loss: 0.1589 - val_accuracy: 0.9474
# Epoch 46/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0231 - accuracy: 0.9949 - val_loss: 0.1748 - val_accuracy: 0.9536
# Epoch 47/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9979 - val_loss: 0.1537 - val_accuracy: 0.9505
# Epoch 48/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 0.9979 - val_loss: 0.1571 - val_accuracy: 0.9474
# Epoch 49/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 0.9964 - val_loss: 0.1634 - val_accuracy: 0.9505
# Epoch 50/50
# 61/61 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9985 - val_loss: 0.1633 - val_accuracy: 0.9443
# 61/61 [==============================] - 0s 1ms/step
# 11/11 [==============================] - 0s 3ms/step
# Average Precision: 0.7367711036041344
# Average Recall: 0.6513159023720781
# Average F1-score: 0.6856928273131508
# Average AUC-ROC: 0.7899089340107094
# average val accuracy 0.8592600737299237
# average train accuracy 0.9522347279957363

# %% [markdown]
# # Model - 2 - ANN Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score,accuracy_score

# Load the dataset
#df = pd.read_csv('data.csv')

# Preprocess the data (e.g., handle missing values, normalize/scale features)

# Split the dataset into training and validation sets
df = pd.read_csv('train.csv')
train_data1 = df.iloc[:, [7, 8, 21, 22, 24, 25, 27, 29]]
train_labels = df.iloc[:, [0]]
dftest = pd.read_csv('test.csv')
val_data1 = dftest.iloc[:, [7, 8, 21, 22, 24, 25, 27, 29]]
val_labels = dftest.iloc[:, [0]]

# Create an instance of StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data
scaler.fit(train_data1)

# Scale the training data
train_data = scaler.transform(train_data1)
train_l = train_labels.to_numpy()
# Scale the validation data
val_data = scaler.transform(val_data1)
val_l = val_labels.to_numpy()
# Reshape the data for CNN input
train_data = train_data.reshape(train_data.shape[0], train_data.shape[1], 1)
val_data = val_data.reshape(val_data.shape[0], val_data.shape[1], 1)

# Define the CNN model
model = Sequential()
model.add(Dense(32,activation='relu',input_shape=(8,)))
model.add(Dense(32,activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16,activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(2,activation='softmax'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# Define the number of folds for cross-validation
num_folds = 7

# Perform k-fold cross-validation
kf = KFold(n_splits=num_folds, shuffle=True)

train_scores = []
precision_scores = []
recall_scores = []
f1_scores = []
auc_roc_scores = []
val_scores = []
best_model = None
best_auc_roc = 0.0
for train_index, val_index in kf.split(train_data):
    # Split the data into training and validation sets for the current fold
    train_fold_data, val_fold_data = train_data[train_index], train_data[val_index]
    train_fold_labels, val_fold_labels = train_l[train_index], train_l[val_index]

    # Train the model on the current fold
    history = model.fit(train_fold_data, train_fold_labels, epochs=50, batch_size=32, validation_data=(val_fold_data, val_fold_labels))

    # Evaluate the model on the training and validation sets of the current fold
    train_predictions = model.predict(train_fold_data)
    val_predictions = model.predict(val_fold_data)
    val_predictions = np.round(val_predictions)

    # Calculate accuracy scores for training and validation sets
    train_acc = model.evaluate(train_fold_data, train_fold_labels, verbose=0)[1]
    val_acc = model.evaluate(val_fold_data, val_fold_labels, verbose=0)[1]

    train_scores.append(train_acc)
    val_scores.append(val_acc)
    
    auc_roc = roc_auc_score(val_fold_labels, val_predictions)
    
    precision = precision_score(val_fold_labels, val_predictions)
    recall = recall_score(val_fold_labels, val_predictions)
    f1 = f1_score(val_fold_labels, val_predictions)
    auc_roc = roc_auc_score(val_fold_labels, val_predictions)

    precision_scores.append(precision)
    recall_scores.append(recall)
    f1_scores.append(f1)
    auc_roc_scores.append(auc_roc)


# Compute the average scores across all folds
avg_precision = np.mean(precision_scores)
avg_recall = np.mean(recall_scores)
avg_f1 = np.mean(f1_scores)
avg_auc_roc = np.mean(auc_roc_scores)
avg_val_acc=np.mean(val_scores)
avg_train_acc=np.mean(train_scores)
print('Average Precision:', avg_precision)
print('Average Recall:', avg_recall)
print('Average F1-score:', avg_f1)
print('Average AUC-ROC:', avg_auc_roc)
print('average val accuracy',avg_val_acc)
print('average train accuracy',avg_train_acc)
# Calculate bias and variance

# Plot bias and variance
# plt.bar(['Bias', 'Variance'], [bias, variance])
# plt.xlabel('Error Type')
# plt.ylabel('Error Value')
# plt.title('Bias-Variance Tradeoff')
# plt.show()

# %%
#create a bucket bucket1cap
#in the anaconda prompt run aws configure  AKIATHSXV4W4GFVU6YI3  xSKizIhCJcdaCigAqImD8MjUeRT9ZOSDsMJd8xw3
#should create iam roles and iam user
#in the vs code create a virtual env called myenv (conda create -p myenv python=3.9)
#activate that myenv (conda activat myenv/)
#install all packages in that env
#before running estimator.fit run the below cell (import boto3 boto3.setup_default_session(region_name="ap-south-1") )

# %%
import sagemaker
import boto3
import pandas as pd
region_name = 'ap-south-1'
sm_boto3 = boto3.client("sagemaker",region_name=region_name)
sess = sagemaker.Session(boto_session=boto3.Session(region_name=region_name))


region = sess.boto_session.region_name

bucket = 'tranformeddatabucketcap' # Mention the created S3 bucket name here

print("Using bucket"+bucket)
# Out:
# Using buckettranformeddatabucketcap

# %%
df = pd.read_csv('train.csv')
train_data1 = df.iloc[:, [7, 8,9,30 ,23,25, 22,  26, 28,27, ]]
train_labels = df.iloc[:, [0]]
dftest = pd.read_csv('test.csv')
val_data1 = dftest.iloc[:, [7, 8,9,30,23,25, 22,  26,28, 27, ]]
val_labels = dftest.iloc[:, [0]]

# %%
train_data1.isnull().sum()
# Out:
# age      0
# bmi      0
# waist    0
# fglu     0
# c1p      0
# alt      0
# ghp      0
# trig     0
# ins      0
# ggt      0
# dtype: int64

# %%
val_data1.isnull().sum()
# Out:
# age      0
# bmi      0
# waist    0
# fglu     0
# c1p      0
# alt      0
# ghp      0
# trig     0
# ins      0
# ggt      0
# dtype: int64

# %%
# send data to S3. SageMaker will take training data from s3

sk_prefix = "nafld_detection"

trainpath = "s3://tranformeddatabucketcap/train.csv"

testpath = "s3://tranformeddatabucketcap/test.csv"
print(trainpath)
print(testpath)
# Out:
# s3://tranformeddatabucketcap/train.csv
# s3://tranformeddatabucketcap/test.csv

# %%
# %%writefile script.py

import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score
import joblib
import boto3
import pathlib
from io import StringIO
import argparse
import joblib
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import recall_score, f1_score, roc_auc_score






def model_fn(model_dir):
    clf = joblib.load(os.path.join(model_dir, "model.joblib"))    
    return clf 
if __name__=="__main__":
    print("[INFO] Extracting arguments")
    parser = argparse.ArgumentParser()
    # hyperparameters sent by the client are passed as command-line arguments to the script.
    parser.add_argument("--n_estimators", type=int, default=100)
    parser.add_argument("--random_state", type=int, default=0)

# Data, model, and output directories
    parser.add_argument("--model-dir", type=str, default=os.environ.get("SM_MODEL_DIR")) 
    parser.add_argument("--train", type=str, default=os.environ.get("SM_CHANNEL_TRAIN"))
    parser.add_argument("--test", type=str, default=os.environ.get("SM_CHANNEL_TEST"))
    parser.add_argument("--train-file", type=str, default="train.csv")
    parser.add_argument("--test-file", type=str, default="test.csv")
    
    args, _ = parser.parse_known_args()

    #print("SKLearn Version: ", sklearn.version)
    #print("Joblib Version: ", joblib.version)

    print("[INFO] Reading data")
    print()
    train_df = pd.read_csv(os.path.join(args.train, args.train_file))
    test_df = pd.read_csv(os.path.join(args.test, args.test_file))

    features = list(train_df.columns)
    label=features.pop(0)

    print("Building training and testing datasets")
    print()
    X_train =train_df [features]
    X_test = test_df[features]
    y_train = train_df[label]
    y_test = test_df[label]

    print('Column order: ')
    print (features)
    print()
    print("Label column is: ", label)
    print()
    print("Data Shape: ")
    print()
    print("---- SHAPE OF TRAINING DATA (70%) ----")
    print(X_train.shape)
    print(y_train.shape)
    print()
    print("---- SHAPE OF TESTING DATA (30%) ----")
    print(X_test.shape)
    print(y_test.shape)
    print()
    print("Training RandomForest Model....")
    print()
    model=RandomForestClassifier(n_estimators=args.n_estimators,random_state=args.random_state)
    model.fit(X_train,y_train)
    print()
    model_path= os.path.join(args.model_dir,"model.joblib")
    joblib.dump(model,model_path)
    print("model persisted at "+ model_path)
    print()
    
    y_pred_test = model.predict(X_test)
    test_acc = accuracy_score(y_test,y_pred_test)
    test_rep = classification_report(y_test,y_pred_test)
    print()
    print("---- METRICS RESULTS FOR TESTING DATA ----")
    print()
    print("Total Rows are: ", X_test.shape[0])
    print('[TESTING] Model Accuracy is: ', test_acc)
    print('[TESTING] Testing Report: ')
    print(test_rep)
# Out:
# Overwriting script.py

# %%
from sagemaker.sklearn.estimator import SKLearn

FRAMEWORK_VERSION = "0.23-1"

sklearn_estimator = SKLearn(
     entry_point="script.py",
     role="arn:aws:iam::222448444856:role/service-role/SageMaker-DataEngineer",
     instance_count=1,
     instance_type="ml.m5.large",
     framework_version=FRAMEWORK_VERSION,
     base_job_name="RF-custom-sklearn",
     use_spot_instances = True,
     max_wait=7200,
     max_run=3600,
     region_name="ap-south-1"
    )

# %%
sklearn_estimator.fit({"train":trainpath,"test":testpath},wait=True)
# Out:
# INFO:sagemaker:Creating training-job with name: RF-custom-sklearn-2024-04-12-10-17-32-243
# 2024-04-12 10:17:36 Starting - Starting the training job...
# 2024-04-12 10:17:51 Starting - Preparing the instances for training...
# 2024-04-12 10:18:35 Downloading - Downloading input data...
# 2024-04-12 10:19:05 Downloading - Downloading the training image...
# 2024-04-12 10:19:40 Training - Training image download completed. Training in progress...2024-04-12 10:19:45,581 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2024-04-12 10:19:45,585 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-04-12 10:19:45,629 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2024-04-12 10:19:45,776 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-04-12 10:19:45,789 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-04-12 10:19:45,800 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-04-12 10:19:45,809 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "RF-custom-sklearn-2024-04-12-10-17-32-243",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-south-1-222448444856/RF-custom-sklearn-2024-04-12-10-17-32-243/source/sourcedir.tar.gz",
#     "module_name": "script",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "script.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=script.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-south-1-222448444856/RF-custom-sklearn-2024-04-12-10-17-32-243/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"RF-custom-sklearn-2024-04-12-10-17-32-243","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-south-1-222448444856/RF-custom-sklearn-2024-04-12-10-17-32-243/source/sourcedir.tar.gz","module_name":"script","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"},"user_entry_point":"script.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
# Invoking script with the following command:
# /miniconda3/bin/python script.py
# [INFO] Extracting arguments
# [INFO] Reading data
# Building training and testing datasets
# Column order:
# ['age', 'bmi', 'waist', 'fglu', 'c1p', 'ghp', 'alt', 'trig', 'ins', 'ggt']
# Label column is:  us
# Data Shape:
# ---- SHAPE OF TRAINING DATA (70%) ----
# (2265, 10)
# (2265,)
# ---- SHAPE OF TESTING DATA (30%) ----
# (970, 10)
# (970,)
# Training RandomForest Model....
# model persisted at /opt/ml/model/model.joblib
# ---- METRICS RESULTS FOR TESTING DATA ----
# Total Rows are:  970
# [TESTING] Model Accuracy is:  0.7855670103092783
# [TESTING] Testing Report:
#               precision    recall  f1-score   support
#            0       0.81      0.92      0.87       725
#            1       0.63      0.38      0.47       245
#     accuracy                           0.79       970
#    macro avg       0.72      0.65      0.67       970
# weighted avg       0.77      0.79      0.77       970
# 2024-04-12 10:19:47,464 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2024-04-12 10:20:06 Uploading - Uploading generated training model
# 2024-04-12 10:20:06 Completed - Training job completed
# Training seconds: 91
# Billable seconds: 42
# Managed Spot Training savings: 53.8%

# %%
import boto3

boto3.setup_default_session(region_name="ap-south-1")  # Or any other supported region

# %%
sklearn_estimator.latest_training_job.wait(logs="None") 
artifact = sm_boto3.describe_training_job(
    TrainingJobName=sklearn_estimator.latest_training_job.name )["ModelArtifacts"]["S3ModelArtifacts"]

print("Model artifact persisted at"+artifact)
# Out:
# 2024-04-12 10:20:06 Starting - Preparing the instances for training
# 2024-04-12 10:20:06 Downloading - Downloading the training image
# 2024-04-12 10:20:06 Training - Training image download completed. Training in progress.
# 2024-04-12 10:20:06 Uploading - Uploading generated training model
# 2024-04-12 10:20:06 Completed - Training job completed
# Model artifact persisted ats3://sagemaker-ap-south-1-222448444856/RF-custom-sklearn-2024-04-12-10-17-32-243/output/model.tar.gz

# %%
#creating end points is balance

# %%
artifact
# Out:
# 's3://sagemaker-ap-south-1-222448444856/RF-custom-sklearn-2024-04-12-10-17-32-243/output/model.tar.gz'

# %%
from sagemaker.sklearn.model import SKLearnModel 
from time import gmtime, strftime
model_name = "Custom-sklearn-model-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
model = SKLearnModel(
name = model_name,
model_data=artifact,
role="arn:aws:iam::222448444856:role/service-role/SageMaker-DataEngineer",
entry_point="script.py",
framework_version=FRAMEWORK_VERSION,)

# %%
model_name
# Out:
# 'Custom-sklearn-model-2024-04-12-10-41-59'

# %%
endpoint_name = "Custom-sklearn-model-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime()) 
print("EndpointName={}".format(endpoint_name))
predictor = model.deploy(
initial_instance_count=1,
instance_type="ml.m4.xlarge",
endpoint_name=endpoint_name)
# Out:
# EndpointName=Custom-sklearn-model-2024-04-12-10-47-51
# INFO:sagemaker:Creating model with name: Custom-sklearn-model-2024-04-12-10-41-59
# INFO:sagemaker:Creating endpoint-config with name Custom-sklearn-model-2024-04-12-10-47-51
# INFO:sagemaker:Creating endpoint with name Custom-sklearn-model-2024-04-12-10-47-51
# -----!

# %%
val_data1[0:2].values.tolist()
# Out:
# [[48.0, 25.0, 94.0, 271.70001, 0.211, 9.0, 9.1000004, 94.0, 48.490002, 15.0],
#  [50.0,
#   25.1,
#   91.5,
#   96.300003,
#   0.29499999,
#   18.0,
#   5.9000001,
#   204.0,
#   8.9200001,
#   22.0]]

# %%
print(predictor.predict(val_data1[0:4].values.tolist()))
# Out:
# [0 0 0 1]

# %%
sm_boto3.delete_endpoint(EndpointName=endpoint_name)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sm_boto3.delete_endpoint(EndpointName=endpoint_name)
#
# File c:\Users\perum\anaconda3\myenv\lib\site-packages\botocore\client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\perum\anaconda3\myenv\lib\site-packages\botocore\client.py:1021, in BaseClient._make_api_call(self, operation_name, api_params)
#    1017     error_code = error_info.get("QueryErrorCode") or error_info.get(
#    1018         "Code"
#    1019     )
#    1020     error_class = self.exceptions.from_code(error_code)
# -> 1021     raise error_class(parsed_response, operation_name)
#    1022 else:
#    1023     return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the DeleteEndpoint operation: Could not find endpoint "Custom-sklearn-model-2024-04-12-10-47-51".
